# %% [markdown]
# #DATASCI W261: Machine Learning at Scale

# %% [markdown]
# # Write some words to a file

# %%
# !echo foo foo quux labs foo bar quux > WordCount.txt

# %% [markdown]
# # MrJob class for wordcount

# %%
# %%writefile WordCount.py
from mrjob.job import MRJob
from mrjob.step import MRJobStep
import re
 
WORD_RE = re.compile(r"[\w']+")
 
class MRWordFreqCount(MRJob):
    def mapper(self, _, line):
        for word in WORD_RE.findall(line):
            yield word.lower(), 1

    def combiner(self, word, counts):
        yield word, sum(counts)

    def reducer(self, word, counts):
        yield word, sum(counts)

if __name__ == '__main__':
    MRWordFreqCount.run()
# Out:
# Writing WordCount.py

# %% [markdown]
# The code above is straightforward. Mapper outputs (word, 1) key value pairs, and then conbiner combines the sum locally. At last, Reducer sums them up.

# %% [markdown]
# # Run the code in command line

# %%
# !python WordCount.py WordCount.txt
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987
# writing to step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987/step-0-mapper-sorted
# > sort /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987/step-0-mapper_part-00000
# writing to step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# Moving /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987/step-0-reducer_part-00000 -> /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987/output/part-00000
# Streaming final output from /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987/output
# "bar"	1
# "foo"	3
# "labs"	1
# "quux"	2
# removing tmp directory /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160202.034230.071987

# %% [markdown]
# # Run the code through python driver

# %% [markdown]
# ####  Reminder: You cannot use the programmatic runner functionality in the same file as your job class. That is because the file with the job class is sent to Hadoop to be run. Therefore, the job file cannot attempt to start the Hadoop job, or you would be recursively creating Hadoop jobs!

# %% [markdown]
# Use make_runner() to run an MRJob
# 1. seperate driver from mapreduce jobs
# 2. now we can run it within pythonnode book
# 3. In python, typically one class is in each file. Each mrjob job is a seperate class, should be in a seperate file

# %%
from WordCount import MRWordFreqCount
mr_job = MRWordFreqCount(args=['WordCount.txt'])
with mr_job.make_runner() as runner: 
    runner.run()
    # stream_output: get access of the output 
    for line in runner.stream_output():
        print mr_job.parse_output_line(line)
# Out:
# ('bar', 1)
# ('foo', 3)
# ('labs', 1)
# ('quux', 2)

# %%
! python WordCount.py -r emr s3://hvcemrbucket/output/hw5/left_in.tab
# Out:
# Got unexpected keyword arguments: ssh_tunnel
# looking for configs in /Users/hetal/.mrjob.conf
# using configs in /Users/hetal/.mrjob.conf
# Active configuration:
# {'additional_emr_info': None,
#  'ami_version': 'latest',
#  'aws_access_key_id': 'AKIAIJ4DCQ7XW5SNPBFA',
#  'aws_availability_zone': None,
#  'aws_region': 'us-west-1',
#  'aws_secret_access_key': 'qQ0ckLw45IKN/KG+tPxxqmmJu2HjSBdfpND9njqd',
#  'aws_security_token': None,
#  'base_tmp_dir': '/var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T',
#  'bootstrap': [],
#  'bootstrap_actions': [],
#  'bootstrap_cmds': [],
#  'bootstrap_files': [],
#  'bootstrap_mrjob': True,
#  'bootstrap_python_packages': [],
#  'bootstrap_scripts': [],
#  'check_emr_status_every': 30,
#  'check_input_paths': True,
#  'cleanup': ['ALL'],
#  'cleanup_on_failure': ['JOB'],
#  'cmdenv': {},
#  'ec2_core_instance_bid_price': None,
#  'ec2_core_instance_type': 'm1.medium',
#  'ec2_instance_type': None,
#  'ec2_key_pair': 'ucb_w261',
#  'ec2_key_pair_file': '/Users/hetal/programming/W261/ucb_w261.pem',
#  'ec2_master_instance_bid_price': None,
#  'ec2_master_instance_type': 'm1.medium',
#  'ec2_slave_instance_type': None,
#  'ec2_task_instance_bid_price': None,
#  'ec2_task_instance_type': None,
#  'emr_action_on_failure': None,
#  'emr_api_params': {},
#  'emr_endpoint': None,
#  'emr_job_flow_id': None,
#  'emr_job_flow_pool_name': 'default',
#  'emr_tags': {},
#  'enable_emr_debugging': None,
#  'hadoop_extra_args': [],
#  'hadoop_streaming_jar': None,
#  'hadoop_streaming_jar_on_emr': '/home/hadoop/contrib/streaming/hadoop-streaming.jar',
#  'hadoop_version': None,
#  'iam_instance_profile': None,
#  'iam_job_flow_role': None,
#  'iam_service_role': None,
#  'interpreter': ['python'],
#  'job_name': None,
#  'jobconf': {},
#  'label': None,
#  'max_hours_idle': None,
#  'mins_to_end_of_hour': 5.0,
#  'num_ec2_core_instances': 4,
#  'num_ec2_instances': 1,
#  'num_ec2_task_instances': 0,
#  'owner': 'hetal',
#  'pool_emr_job_flows': None,
#  'pool_wait_minutes': 0,
#  'python_archives': [],
#  'python_bin': ['python'],
#  's3_endpoint': None,
#  's3_log_uri': None,
#  's3_scratch_uri': None,
#  's3_sync_wait_time': 5.0,
#  's3_upload_part_size': 100,
#  'setup': [],
#  'setup_cmds': [],
#  'setup_scripts': [],
#  'sh_bin': ['/bin/sh', '-ex'],
#  'ssh_bin': ['ssh'],
#  'ssh_bind_ports': [40001,
#                     40002,
#                     40003,
#                     40004,
#                     40005,
#                     40006,
#                     40007,
#                     40008,
#                     40009,
#                     40010,
#                     40011,
#                     40012,
#                     40013,
#                     40014,
#                     40015,
#                     40016,
#                     40017,
#                     40018,
#                     40019,
#                     40020,
#                     40021,
#                     40022,
#                     40023,
#                     40024,
#                     40025,
#                     40026,
#                     40027,
#                     40028,
#                     40029,
#                     40030,
#                     40031,
#                     40032,
#                     40033,
#                     40034,
#                     40035,
#                     40036,
#                     40037,
#                     40038,
#                     40039,
#                     40040,
#                     40041,
#                     40042,
#                     40043,
#                     40044,
#                     40045,
#                     40046,
#                     40047,
#                     40048,
#                     40049,
#                     40050,
#                     40051,
#                     40052,
#                     40053,
#                     40054,
#                     40055,
#                     40056,
#                     40057,
#                     40058,
#                     40059,
#                     40060,
#                     40061,
#                     40062,
#                     40063,
#                     40064,
#                     40065,
#                     40066,
#                     40067,
#                     40068,
#                     40069,
#                     40070,
#                     40071,
#                     40072,
#                     40073,
#                     40074,
#                     40075,
#                     40076,
#                     40077,
#                     40078,
#                     40079,
#                     40080,
#                     40728,
#                     40729,
#                     40730,
#                     40731,
#                     40732,
#                     40733,
#                     40734,
#                     40735,
#                     40736,
#                     40737,
#                     40738,
#                     40739,
#                     40740,
#                     40741,
#                     40742,
#                     40743,
#                     40744,
#                     40745,
#                     40746,
#                     40747,
#                     40748,
#                     40749,
#                     40750,
#                     40751,
#                     40752,
#                     40753,
#                     40754,
#                     40755,
#                     40756,
#                     40757,
#                     40758,
#                     40759,
#                     40760,
#                     40761,
#                     40762,
#                     40763,
#                     40764,
#                     40765,
#                     40766,
#                     40767,
#                     40768,
#                     40769,
#                     40770,
#                     40771,
#                     40772,
#                     40773,
#                     40774,
#                     40775,
#                     40776,
#                     40777,
#                     40778,
#                     40779,
#                     40780,
#                     40781,
#                     40782,
#                     40783,
#                     40784,
#                     40785,
#                     40786,
#                     40787,
#                     40788,
#                     40789,
#                     40790,
#                     40791,
#                     40792,
#                     40793,
#                     40794,
#                     40795,
#                     40796,
#                     40797,
#                     40798,
#                     40799,
#                     40800,
#                     40801,
#                     40802,
#                     40803,
#                     40804,
#                     40805,
#                     40806,
#                     40807,
#                     40808,
#                     40809,
#                     40810,
#                     40811,
#                     40812,
#                     40813,
#                     40814,
#                     40815,
#                     40816,
#                     40817,
#                     40818,
#                     40819,
#                     40820,
#                     40821,
#                     40822,
#                     40823,
#                     40824,
#                     40825,
#                     40826,
#                     40827,
#                     40828,
#                     40829,
#                     40830,
#                     40831,
#                     40832,
#                     40833,
#                     40834,
#                     40835,
#                     40836,
#                     40837,
#                     40838,
#                     40839,
#                     40840],
#  'ssh_tunnel_is_open': False,
#  'ssh_tunnel_to_job_tracker': True,
#  'steps_interpreter': ['/Users/hetal/anaconda/bin/python'],
#  'steps_python_bin': ['/Users/hetal/anaconda/bin/python'],
#  'strict_protocols': None,
#  'upload_archives': [],
#  'upload_files': [],
#  'visible_to_all_users': False}
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# using existing scratch bucket mrjob-54195a6c9677a8ce
# using s3://mrjob-54195a6c9677a8ce/tmp/ as our scratch dir on S3
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating tmp directory /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845
# archiving /Users/hetal/anaconda/lib/python2.7/site-packages/mrjob -> /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/mrjob.tar.gz as mrjob/
# writing master bootstrap script to /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/b.py
# BOOTSTRAP: #!/bin/sh -ex
# BOOTSTRAP:
# BOOTSTRAP: # store $PWD
# BOOTSTRAP: __mrjob_PWD=$PWD
# BOOTSTRAP:
# BOOTSTRAP: # download files and mark them executable
# BOOTSTRAP: hadoop fs -copyToLocal s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/mrjob.tar.gz $__mrjob_PWD/mrjob.tar.gz
# BOOTSTRAP: chmod a+x $__mrjob_PWD/mrjob.tar.gz
# BOOTSTRAP:
# BOOTSTRAP: # bootstrap commands
# BOOTSTRAP: __mrjob_PYTHON_LIB=$(python -c 'from distutils.sysconfig import get_python_lib; print get_python_lib()')
# BOOTSTRAP: sudo tar xfz $__mrjob_PWD/mrjob.tar.gz -C $__mrjob_PYTHON_LIB
# BOOTSTRAP: sudo python -m compileall -f $__mrjob_PYTHON_LIB/mrjob && true
# BOOTSTRAP:
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# > /Users/hetal/anaconda/bin/python /Users/hetal/programming/W261/UCB_MIDS_W261/week4/WordCount.py --steps
# Copying non-input files into s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# uploading /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/mrjob.tar.gz -> s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/mrjob.tar.gz
# uploading /Users/hetal/programming/W261/UCB_MIDS_W261/week4/WordCount.py -> s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/WordCount.py
# uploading /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/b.py -> s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/b.py
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# creating IAM connection
# Can't access IAM API, trying default instance profile: EMR_EC2_DefaultRole
# creating IAM connection
# Can't access IAM API, trying default service role: EMR_DefaultRole
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Calling run_jobflow('WordCount.hetal.20160214.184107.602845', u's3://mrjob-54195a6c9677a8ce/tmp/logs/', ami_version='latest', bootstrap_actions=[boto.emr.bootstrap_action.BootstrapAction(name='master', path=u's3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/b.py', bootstrap_action_args=[])], num_instances=5, master_instance_type='m1.medium', api_params={'JobFlowRole': 'EMR_EC2_DefaultRole', 'ServiceRole': 'EMR_DefaultRole'}, ec2_keyname='ucb_w261', slave_instance_type='m1.medium')
# Job flow created with ID: j-2Q8QMVWEPRIL3
# Created new job flow j-2Q8QMVWEPRIL3
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Calling add_jobflow_steps(u'j-2Q8QMVWEPRIL3', [boto.emr.step.StreamingStep(name='WordCount.hetal.20160214.184107.602845: Step 1 of 1', mapper='python WordCount.py --step-num=0 --mapper', reducer='python WordCount.py --step-num=0 --reducer', action_on_failure='TERMINATE_CLUSTER', cache_files=None, cache_archives=None, step_args=['-files', u's3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/WordCount.py#WordCount.py'], input=['s3://hvcemrbucket/output/hw5/left_in.tab'], output=u's3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/', jar='/home/hadoop/contrib/streaming/hadoop-streaming.jar')])
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 30.3s ago, status STARTING: Provisioning Amazon EC2 capacity
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 61.0s ago, status STARTING: Provisioning Amazon EC2 capacity
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 91.3s ago, status STARTING: Provisioning Amazon EC2 capacity
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 122.2s ago, status STARTING: Provisioning Amazon EC2 capacity
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 152.4s ago, status STARTING: Configuring cluster software
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 183.3s ago, status STARTING: Configuring cluster software
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 213.6s ago, status BOOTSTRAPPING: Running bootstrap actions
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 244.6s ago, status RUNNING: Running step (WordCount.hetal.20160214.184107.602845: Step 1 of 1)
# Opening ssh tunnel to Hadoop job tracker
# Created empty ssh known-hosts file: /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/fake_ssh_known_hosts
# > ssh -o VerifyHostKeyDNS=no -o StrictHostKeyChecking=no -o ExitOnForwardFailure=yes -o UserKnownHostsFile=/var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/fake_ssh_known_hosts -L 40229:localhost:9100 -N -q -i /Users/hetal/programming/W261/ucb_w261.pem hadoop@ec2-54-153-81-248.us-west-1.compute.amazonaws.com
# Connect to job tracker at: http://localhost:40229/jobtracker.jsp
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 275.9s ago, status RUNNING: Running step (WordCount.hetal.20160214.184107.602845: Step 1 of 1)
# Unable to load progress from job tracker
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 306.8s ago, status RUNNING: Running step (WordCount.hetal.20160214.184107.602845: Step 1 of 1)
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job launched 337.1s ago, status RUNNING: Running step (WordCount.hetal.20160214.184107.602845: Step 1 of 1)
# Oops, ssh subprocess exited with return code 255, restarting...
# Opening ssh tunnel to Hadoop job tracker
# Created empty ssh known-hosts file: /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/fake_ssh_known_hosts
# > ssh -o VerifyHostKeyDNS=no -o StrictHostKeyChecking=no -o ExitOnForwardFailure=yes -o UserKnownHostsFile=/var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845/fake_ssh_known_hosts -L 40229:localhost:9100 -N -q -i /Users/hetal/programming/W261/ucb_w261.pem hadoop@ec2-54-153-81-248.us-west-1.compute.amazonaws.com
# Connect to job tracker at: http://localhost:40229/jobtracker.jsp
# Waiting 30.0 seconds...
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Job completed.
# Running time was 105.0s (not counting time spent waiting for the EC2 instances)
# creating EMR connection (to elasticmapreduce.us-west-1.amazonaws.com)
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Search s3://mrjob-54195a6c9677a8ce/tmp/logs/j-2Q8QMVWEPRIL3/jobs/ for logs
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# Ignore s3://mrjob-54195a6c9677a8ce/tmp/logs/j-2Q8QMVWEPRIL3/jobs/job_201602141843_0001_conf.xml
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 305
#   File Output Format Counters :
#     Bytes Written: 58
#   FileSystemCounters:
#     FILE_BYTES_READ: 210
#     FILE_BYTES_WRITTEN: 646794
#     HDFS_BYTES_READ: 1581
#     S3_BYTES_READ: 305
#     S3_BYTES_WRITTEN: 58
#   Job Counters :
#     Launched map tasks: 17
#     Launched reduce tasks: 10
#     Rack-local map tasks: 17
#     SLOTS_MILLIS_MAPS: 201816
#     SLOTS_MILLIS_REDUCES: 160163
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 13750
#     Combine input records: 6
#     Combine output records: 6
#     Map input bytes: 33
#     Map input records: 3
#     Map output bytes: 58
#     Map output materialized bytes: 1974
#     Map output records: 6
#     Physical memory (bytes) snapshot: 6048854016
#     Reduce input groups: 6
#     Reduce input records: 6
#     Reduce output records: 6
#     Reduce shuffle bytes: 1974
#     SPLIT_RAW_BYTES: 1581
#     Spilled Records: 12
#     Total committed heap usage (bytes): 5631623168
#     Virtual memory (bytes) snapshot: 22861119488
# Streaming final output from s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# "3"	1
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# "1"	1
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# "antonio"	1
# "emparedados"	1
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# "2"	1
# "alfreds"	1
# removing tmp directory /var/folders/91/cjfxt7ys6958qll6vjtgwwfw0000gn/T/WordCount.hetal.20160214.184107.602845
# Removing all files in s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# creating S3 connection (to s3-us-west-1.amazonaws.com)
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/WordCount.py
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/b.py
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/files/mrjob.tar.gz
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/_SUCCESS
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/part-00000
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/part-00001
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/part-00002
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/part-00003
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845/output/part-00004
# deleting s3://mrjob-54195a6c9677a8ce/tmp/WordCount.hetal.20160214.184107.602845